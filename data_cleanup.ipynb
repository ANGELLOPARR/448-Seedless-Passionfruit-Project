# %%
# imports
import pandas as pd
import numpy as np

phenotype_file = 'pgen.1007217.s010.xlsx'

# %% [markdown]
# ## Extract Phenotype data from yeast study

# %%
with pd.ExcelFile(phenotype_file) as xlsx:
    yeast_info = pd.read_excel(xlsx, "Column Information")
    yeast_pheno_data = pd.read_excel(xlsx, "DATA")
# Out:
# /opt/homebrew/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
yeast_pheno_data
# Out:
#      Strains                                 Niche           Location  \
# 0    273614N                              Clinical      Newcastle, UK
# 1    378604X                              Clinical      Newcastle, UK
# 2      BC187                    Other Fermentation   Napa Valley, USA
# 3    CBS7960  Industrial fermentation (sugar cane)  Sau Paulo, Brazil
# 4    CLIB324                                Bakery            Vietnam
# ..       ...                                   ...                ...
# 160   YPS163                                   Oak  Pennsylvania, USA
# 161   YPS606                       Natural Isolate       Woodland, PA
# 162      YS2                                Bakery          Australia
# 163      YS4                                Bakery    The Netherlands
# 164      YS9                                Bakery          Singapore
#
#      SynH Final OD600  SynH Percent glucose consumed  \
# 0              5.5000                      50.000000
# 1              0.3625                       2.868391
# 2              6.5600                      69.178853
# 3              6.5125                      58.717660
# 4              3.5750                      30.033746
# ..                ...                            ...
# 160            7.6750                      68.110236
# 161            6.9300                      65.466817
# 162            6.9500                      66.704162
# 163            3.9625                      50.899888
# 164            7.4875                      75.084364
#
#      HT Tolerance based on OD600  HT Tolerance based on glucose consumption  \
# 0                      70.512821                                  61.313348
# 1                       3.091684                                   3.377585
# 2                      65.257399                                  70.055980
# 3                      67.139175                                  59.588245
# 4                      63.839286                                  56.576727
# ..                           ...                                        ...
# 160                    75.152999                                  81.034201
# 161                    63.753450                                  76.798901
# 162                    57.736241                                  80.138287
# 163                    37.206573                                  54.243537
# 164                    66.041896                                  80.370678
#
#      Number of SNPs compared to S288c (ref Strain)   \
# 0                                             48534
# 1                                             46222
# 2                                             42617
# 3                                             47900
# 4                                             46951
# ..                                              ...
# 160                                           61484
# 161                                           60376
# 162                                           42187
# 163                                           86918
# 164                                           61764
#
#      Percent pairwise genetic divergence  Percent of Heterozygous SNPs  \
# 0                               0.401107                             3
# 1                               0.382000                             3
# 2                               0.352207                             2
# 3                               0.395868                             3
# 4                               0.388025                            98
# ..                                   ...                           ...
# 160                             0.508132                             2
# 161                             0.498975                             3
# 162                             0.348653                             2
# 163                             0.718331                            73
# 164                             0.510446                            59
#
#      Population based on PCA coordinates
# 0                                      8
# 1                                      8
# 2                                      1
# 3                                      1
# 4                                      8
# ..                                   ...
# 160                                    3
# 161                                    3
# 162                                    1
# 163                                    8
# 164                                    8
#
# [165 rows x 11 columns]

# %% [markdown]
# ## Drop unwanted rows (only 4 columns for toxin tolerance)
# ### Also clean column names since GAPIT needs tab-delimited file

# %%
pheno_data = yeast_pheno_data.drop(columns=['Niche', 'Location'])
pheno_data = pheno_data.iloc[:,:5]
cleaned_columns = [col.replace(' ', '_') for col in pheno_data.columns]
pheno_data.columns = cleaned_columns
pheno_data
# Out:
#      Strains  SynH_Final_OD600  SynH_Percent_glucose_consumed  \
# 0    273614N            5.5000                      50.000000
# 1    378604X            0.3625                       2.868391
# 2      BC187            6.5600                      69.178853
# 3    CBS7960            6.5125                      58.717660
# 4    CLIB324            3.5750                      30.033746
# ..       ...               ...                            ...
# 160   YPS163            7.6750                      68.110236
# 161   YPS606            6.9300                      65.466817
# 162      YS2            6.9500                      66.704162
# 163      YS4            3.9625                      50.899888
# 164      YS9            7.4875                      75.084364
#
#      HT_Tolerance_based_on_OD600  HT_Tolerance_based_on_glucose_consumption
# 0                      70.512821                                  61.313348
# 1                       3.091684                                   3.377585
# 2                      65.257399                                  70.055980
# 3                      67.139175                                  59.588245
# 4                      63.839286                                  56.576727
# ..                           ...                                        ...
# 160                    75.152999                                  81.034201
# 161                    63.753450                                  76.798901
# 162                    57.736241                                  80.138287
# 163                    37.206573                                  54.243537
# 164                    66.041896                                  80.370678
#
# [165 rows x 5 columns]

# %% [markdown]
# ## Export to *tab-delimited* file!!

# %%
pheno_data.to_csv("pheno_data.tsv", sep='\t')
